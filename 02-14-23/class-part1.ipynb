# %%
import os
import numpy as np
from skimage import io, img_as_float
import shutil

# %%
img = io.imread("/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Image Processing/SP+AN/image folder/stars.jpg")
img.shape
# Out:
# (4000, 6000, 3)

# %% [markdown]
# - Normalising the gray level values

# %%
imgFloat = img_as_float(img)
imgFloat.dtype
# Out:
# dtype('float64')

# %%
img[3000][5000][1], imgFloat[3000][5000][1]
# Out:
# (8, 0.03137254901960784)

# %%
import cv2

# %%
grayImg =
