# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread(input("Enter image path"))
plt.imshow(img)
plt.savefig("/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Image Processing/SP+AN/AN_Image/dog-output.jpg")
# Out:
# Enter image path/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Image Processing/SP+AN/AN_Image/dog1.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Image Processing/SP+AN/Barca Images/"

# %%
import os

# %%
plt.figure(figsize=(10, 6))

images = os.listdir(path)
for i, img in enumerate(images):
  image = plt.imread(os.path.join(path, img))
  plt.subplot(2, 2, i+1)
  plt.imshow(image)

# %%
img1 = plt.imread("/content/drive/MyDrive/#2-M.Sc Computer Science [SXC]/1st Year/Books and notes/Sem 4/Image Processing/SP+AN/Barca Images/ecfevdpwkaakfii.jpg")
R, G, B= img1[:, :, 0], img1[:, :, 1], img1[:, :, 2]
gray = .2989*R + .5870*G + .114*B

# %%
plt.imshow(R, cmap="Reds")

# %%
plt.imshow(B, cmap="Blues")

# %%
plt.imshow(G, cmap="Greens")

# %%
plt.imshow(gray.T, cmap="gray")

# %%
bw = np.copy(gray)
for i in range(gray.shape[0]):
  for j in range(gray.shape[1]):
    bw[i][j] = 255 if gray[i][j] > 127 else 0

plt.imshow(bw, cmap="gray")

# %%
plt.imshow(255 - bw, cmap="gray")

# %%
plt.imshow(gray, cmap="gray")
